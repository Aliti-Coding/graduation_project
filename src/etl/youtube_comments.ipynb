# %%
import googleapiclient.discovery
import pandas as pd
import os

import requests_cache
requests_cache.install_cache("yt_api")

# %%
def connect_yt_data_api():
    api_service_name = "youtube"
    api_version = "v3"

    with open("../../google_api_key.key") as file:
        DEVELOPER_KEY = file.read()

    youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)
    
    return youtube

def get_comments(videoId:str=None, allThreadsRelatedToChannelId:str=None, pageToken=None):
    if not videoId and not allThreadsRelatedToChannelId:
        raise Exception("no video id or channelId specified.")

    
    youtube = connect_yt_data_api()

    request = youtube.commentThreads().list(
        part="snippet",
        allThreadsRelatedToChannelId=allThreadsRelatedToChannelId,
        videoId=videoId,
        maxResults=100,
        pageToken=pageToken
    )

    response = request.execute()
    return response

# %%
def get_channel_id(channelName):

    youtube = connect_yt_data_api()
    
    request = youtube.channels().list(
        part="statistics",
        forUsername="TeslaMotors"
    )
    channels = request.execute()

    return channels["items"][0]["id"]

# %%
get_channel_id("TeslaMotors")
# Out:
# 'UC5WjFrtBdufl6CZojX3D8dQ'

# %%
def extract_comments(videoId, pages=1):
    parsed_comments = []
    
    pageToken=None
    
    for _ in range(pages):
        comments = get_comments(videoId=videoId, pageToken=pageToken)
        pageToken = comments["nextPageToken"]
        
        for comment in comments["items"]:
            tplc = comment["snippet"]["topLevelComment"]["snippet"]

            parsed_comment = {
                "textOriginal":tplc["textOriginal"],
                "authorDisplayName":tplc["authorDisplayName"],
                "publishedAt":tplc["publishedAt"],
                "likeCount":tplc["likeCount"]
            }
            
            parsed_comments.append(parsed_comment)

        
    return parsed_comments

# %%
cs = extract_comments("eelCWETObJ8", pages=2)

# %%
cs
# Out:
# [{'textOriginal': 'Alo bre vracaj mikiju kanal',
#   'authorDisplayName': 'Ogi Mi',
#   'publishedAt': '2023-02-16T13:26:48Z',
#   'likeCount': 1},
#  {'textOriginal': 'Love it love it love it. But where are the ladies?',
#   'authorDisplayName': 'John Burger',
#   'publishedAt': '2023-02-16T13:03:30Z',
#   'likeCount': 0},
#  {'textOriginal': '😂😂😂.... Tesla Insurance in MA please!! 🙏 🙏 🙏',
#   'authorDisplayName': 'John Grimble',
#   'publishedAt': '2023-02-16T12:52:08Z',
#   'likeCount': 0},
#  {'textOriginal': 'MIHAJLOOO',
#   'authorDisplayName': 'Uros Peric',
#   'publishedAt': '2023-02-16T12:18:18Z',
#   'likeCount': 1},
#  {'textOriginal': 'Mater ti poljubi',
#   'authorDisplayName': 'fran rili zagorec',
#   'publishedAt': '2023-02-16T12:13:48Z',
#   'likeCount': 0},
#  {'textOriginal': 'HACKER GIVE BACK THE CHANNEL',
#   'authorDisplayName': 'vesonfire',
#   'publishedAt': '2023-02-16T11:23:35Z',
#   'likeCount': 1},
#  {'textOriginal': 'Hakovali ste mihajlov kanal sram vas bilo',
#   'authorDisplayName': 'DraganXD',
#   'publishedAt': '2023-02-16T10:58:51Z',
#   'likeCount': 0},
#  {'textOriginal': 'Mihajlo madic?🤣',
#   'authorDisplayName': 'Robbie',
#   'publishedAt': '2023-02-16T10:57:39Z',
#   'likeCount': 0},
#  {'textOriginal': '😻',
#   'authorDisplayName': 'Aadhirai ManiPadma Sathyavathi',
#   'publishedAt': '2023-02-16T10:55:37Z',
#   'likeCount': 0},
#  {'textOriginal': 'HAKOVALI MIHAJLU MADIĆU YT PROFIL',
#   'authorDisplayName': 'Ad3L',
#   'publishedAt': '2023-02-16T10:35:31Z',
#   'likeCount': 1},
#  {'textOriginal': 'Mihajlo madicc',
#   'authorDisplayName': 'doza.simija7',
#   'publishedAt': '2023-02-16T10:33:32Z',
#   'likeCount': 0},
#  {'textOriginal': 'its like a spill over from dexters lab',
#   'authorDisplayName': 'ooga booga',
#   'publishedAt': '2023-02-16T10:26:31Z',
#   'likeCount': 0},
#  {'textOriginal': 'Well, looks like the Project AD-01 line from Xetashell might be faster 😬',
#   'authorDisplayName': 'freaky-Deek',
#   'publishedAt': '2023-02-16T10:07:01Z',
#   'likeCount': 0},
#  {'textOriginal': 'Di je Mihajlo Madić?',
#   'authorDisplayName': 'INVICTUS_MATEO',
#   'publishedAt': '2023-02-16T10:03:08Z',
#   'likeCount': 0},
#  {'textOriginal': "Can we please get more info on Ty's work?",
#   'authorDisplayName': 'Péter Váradi',
#   'publishedAt': '2023-02-16T09:36:28Z',
#   'likeCount': 0},
#  {'textOriginal': 'i want TESLA but i dont hav money',
#   'authorDisplayName': 'therageur',
#   'publishedAt': '2023-02-16T09:17:38Z',
#   'likeCount': 0},
#  {'textOriginal': 'alo mihajlo',
#   'authorDisplayName': 'mqwez1',
#   'publishedAt': '2023-02-16T07:50:10Z',
#   'likeCount': 0},
#  {'textOriginal': '<3 All is full of love. <3',
#   'authorDisplayName': 'flottenheimer',
#   'publishedAt': '2023-02-16T07:04:39Z',
#   'likeCount': 0},
#  {'textOriginal': 'cringiness +10000000',
#   'authorDisplayName': '【豪】HowCC',
#   'publishedAt': '2023-02-16T06:47:48Z',
#   'likeCount': 0},
#  {'textOriginal': 'I want to know what they need a bot that can lift 40k lbs for. That’s crazy!',
#   'authorDisplayName': 'Aaron Rust',
#   'publishedAt': '2023-02-16T05:59:42Z',
#   'likeCount': 0},
#  {'textOriginal': '@0:55 More Cow-bells!\n_Play it again GAR-E_',
#   'authorDisplayName': 'Ivan Kuljis',
#   'publishedAt': '2023-02-16T05:45:48Z',
#   'likeCount': 0},
#  {'textOriginal': 'Warming yo for the lady Optimus, your future tech partner \U0001faf6🏼!  Come with a neurolink connection for free 🙌🏼',
#   'authorDisplayName': 'Enrico Golfetto Masella',
#   'publishedAt': '2023-02-16T05:38:29Z',
#   'likeCount': 1},
#  {'textOriginal': 'Gar E just like me fr',
#   'authorDisplayName': 'Adwait Kulkarni',
#   'publishedAt': '2023-02-16T05:37:37Z',
#   'likeCount': 0},
#  {'textOriginal': '“I like to get Cumfortable…” I can’t tell if I just have a dirty mind, or if that was on purpose…',
#   'authorDisplayName': 'AndrewdoesYT',
#   'publishedAt': '2023-02-16T05:36:42Z',
#   'likeCount': 1},
#  {'textOriginal': "Nice too meet you, Robots. That's why I love Tesla and shareholder @TSLA. Thank you for share",
#   'authorDisplayName': 'Thoai Tran',
#   'publishedAt': '2023-02-16T05:12:55Z',
#   'likeCount': 0},
#  {'textOriginal': 'Bravo miki',
#   'authorDisplayName': 'Vale172r',
#   'publishedAt': '2023-02-16T03:54:14Z',
#   'likeCount': 1},
#  {'textOriginal': "Beware there are crazy spam robots in the chat If it says anything about telegram or you've been selected for something just tell it to F off! Because it's not Tesla.\nThe example is below in the reply!",
#   'authorDisplayName': 'Mr, Nobody.',
#   'publishedAt': '2023-02-16T03:45:35Z',
#   'likeCount': 0},
#  {'textOriginal': 'Bruh even the robots💀',
#   'authorDisplayName': 'Noob codm',
#   'publishedAt': '2023-02-16T03:18:07Z',
#   'likeCount': 0},
#  {'textOriginal': 'The Musk haters can suck it!',
#   'authorDisplayName': 'protoborg',
#   'publishedAt': '2023-02-16T01:54:45Z',
#   'likeCount': 0},
#  {'textOriginal': 'I wish Apple had this sense of humor😂😂',
#   'authorDisplayName': 'Harrison Leininger',
#   'publishedAt': '2023-02-16T01:50:57Z',
#   'likeCount': 0},
#  {'textOriginal': 'Gar-e killing it on the cow bell 👏🥲 0:57',
#   'authorDisplayName': 'Ryan Mcrorie',
#   'publishedAt': '2023-02-16T01:25:11Z',
#   'likeCount': 0},
#  {'textOriginal': 'Mihajlo madic\U0001fae1\U0001fae1\U0001fae1',
#   'authorDisplayName': 'Veljko Stoiljkovic',
#   'publishedAt': '2023-02-16T01:03:27Z',
#   'likeCount': 1},
#  {'textOriginal': 'Ode kanal... E buraz kad klikćeš svuda... Ne da ti se.',
#   'authorDisplayName': 'Laki',
#   'publishedAt': '2023-02-16T00:42:09Z',
#   'likeCount': 2},
#  {'textOriginal': 'I see you’re trying despite the disaster on top.',
#   'authorDisplayName': 'All Hits Taken',
#   'publishedAt': '2023-02-16T00:19:26Z',
#   'likeCount': 1},
#  {'textOriginal': 'So just to throw this out there, Tesla actually gets paid when we watch these videos.... all the competition has to pay to get us to watch their videos... another win for tesla lol',
#   'authorDisplayName': 'David',
#   'publishedAt': '2023-02-16T00:16:43Z',
#   'likeCount': 0},
#  {'textOriginal': '#babydogecoin',
#   'authorDisplayName': 'icy life',
#   'publishedAt': '2023-02-15T23:42:40Z',
#   'likeCount': 0},
#  {'textOriginal': '0:15 Cybertruck Uni-Frame?',
#   'authorDisplayName': 'Brian Tucker',
#   'publishedAt': '2023-02-15T23:01:08Z',
#   'likeCount': 0},
#  {'textOriginal': 'I will invite that musician on my welding.',
#   'authorDisplayName': 'Max Jacoby',
#   'publishedAt': '2023-02-15T22:05:12Z',
#   'likeCount': 0},
#  {'textOriginal': 'Miki wtf',
#   'authorDisplayName': 'Taris Pasa',
#   'publishedAt': '2023-02-15T21:55:22Z',
#   'likeCount': 1},
#  {'textOriginal': 'To jest scam dawaj mi moje oblicza xx wieku spowrotem!!!!',
#   'authorDisplayName': 'RomeMapping',
#   'publishedAt': '2023-02-15T21:38:16Z',
#   'likeCount': 3},
#  {'textOriginal': 'Yep. that was weird. Maybe chat GPT needs a hookup.',
#   'authorDisplayName': 'Timothy Quinn',
#   'publishedAt': '2023-02-15T21:03:11Z',
#   'likeCount': 0},
#  {'textOriginal': 'Where are the women robots? We need women in STEM!!',
#   'authorDisplayName': "Let's Lie Less",
#   'publishedAt': '2023-02-15T21:02:40Z',
#   'likeCount': 0},
#  {'textOriginal': 'And some people find Tesla to be boring 😂',
#   'authorDisplayName': 'Sonja Ullman',
#   'publishedAt': '2023-02-15T20:36:21Z',
#   'likeCount': 0},
#  {'textOriginal': 'Optimus: “I’m sensitive and hard” 😉\nEDIT: Turns out he said “at heart” 😅',
#   'authorDisplayName': 'Cathy Jones',
#   'publishedAt': '2023-02-15T20:33:58Z',
#   'likeCount': 0},
#  {'textOriginal': '🥰',
#   'authorDisplayName': 'NYDER',
#   'publishedAt': '2023-02-15T20:26:27Z',
#   'likeCount': 0},
#  {'textOriginal': '😍😍🥰🥰',
#   'authorDisplayName': 'Michael Sanchez',
#   'publishedAt': '2023-02-15T20:13:08Z',
#   'likeCount': 0},
#  {'textOriginal': 'Hahahaha!!! This is another reason I love Tesla so much 😂👏🏼',
#   'authorDisplayName': 'Adventures in Paradise',
#   'publishedAt': '2023-02-15T19:37:38Z',
#   'likeCount': 0},
#  {'textOriginal': 'TESLA TO THE MOON!!!!',
#   'authorDisplayName': 'King Robinhood',
#   'publishedAt': '2023-02-15T19:11:30Z',
#   'likeCount': 0},
#  {'textOriginal': 'My love robot is CHAT GPT',
#   'authorDisplayName': 'Lyimo Ej',
#   'publishedAt': '2023-02-15T18:29:49Z',
#   'likeCount': 0},
#  {'textOriginal': 'This made my day 😂',
#   'authorDisplayName': 'glademaster',
#   'publishedAt': '2023-02-15T17:51:35Z',
#   'likeCount': 0},
#  {'textOriginal': 'I believe in open source relationships 🤣',
#   'authorDisplayName': 'Ethan Johnston',
#   'publishedAt': '2023-02-15T17:44:00Z',
#   'likeCount': 0},
#  {'textOriginal': "This is why i'm saving my usb cables.",
#   'authorDisplayName': 'Arthur',
#   'publishedAt': '2023-02-15T17:41:38Z',
#   'likeCount': 0},
#  {'textOriginal': 'Look at the diodes on that 73 65 78 79 20 6d 61 63 68 69 6e 65 20 6c 75 62 65 20 6d 65 20 75 70 oh yeah!! you know you need a bit of Hex',
#   'authorDisplayName': 'Capt. Marco Hawk',
#   'publishedAt': '2023-02-15T17:38:42Z',
#   'likeCount': 0},
#  {'textOriginal': 'Open source relationship😂😂😂',
#   'authorDisplayName': 'István Máté',
#   'publishedAt': '2023-02-15T17:24:49Z',
#   'likeCount': 0},
#  {'textOriginal': "This is the greatest thing I've seen from a major company. Testament to what Tesla are doing for humanity with a sprinkle of humour.",
#   'authorDisplayName': 'RvMajor',
#   'publishedAt': '2023-02-15T17:17:47Z',
#   'likeCount': 0},
#  {'textOriginal': 'Joey-2000 is Elon himself isn’t',
#   'authorDisplayName': 'Arthas Chen',
#   'publishedAt': '2023-02-15T17:07:15Z',
#   'likeCount': 0},
#  {'textOriginal': 'Watafak',
#   'authorDisplayName': 'fracka 023',
#   'publishedAt': '2023-02-15T16:58:51Z',
#   'likeCount': 0},
#  {'textOriginal': '😂😅',
#   'authorDisplayName': 'Raphael Walker',
#   'publishedAt': '2023-02-15T16:56:43Z',
#   'likeCount': 0},
#  {'textOriginal': 'Little sister',
#   'authorDisplayName': 'Leo Knives',
#   'publishedAt': '2023-02-15T16:47:05Z',
#   'likeCount': 0},
#  {'textOriginal': '💜💜💜💜💜💜💜💜💜💜💜💜💜💜',
#   'authorDisplayName': 'Leo Knives',
#   'publishedAt': '2023-02-15T16:46:54Z',
#   'likeCount': 0},
#  {'textOriginal': 'Arudino  and Ai my name is jazz welcome to the robot world',
#   'authorDisplayName': 'Divya Nishad',
#   'publishedAt': '2023-02-15T16:42:22Z',
#   'likeCount': 0},
#  {'textOriginal': 'I am amazed at how many channels I love that I am not subbed to why do I do- this',
#   'authorDisplayName': 'Sam the boss',
#   'publishedAt': '2023-02-15T16:37:17Z',
#   'likeCount': 0},
#  {'textOriginal': "this is why tesla doesn't have to spent a mint on selling its products. #CreativityIsLitAF",
#   'authorDisplayName': 'The Pee-On Press',
#   'publishedAt': '2023-02-15T16:24:37Z',
#   'likeCount': 0},
#  {'textOriginal': 'Keep Posting Great #Tesla Content',
#   'authorDisplayName': 'The Electric Man',
#   'publishedAt': '2023-02-15T15:56:02Z',
#   'likeCount': 0},
#  {'textOriginal': "Waste of time! Elon needs to cut some people - this kind of BS is a waste of everyone's time.",
#   'authorDisplayName': 'Dr Fasthouse vonBrainstorm',
#   'publishedAt': '2023-02-15T15:04:39Z',
#   'likeCount': 0},
#  {'textOriginal': 'who else check video quality? 😂',
#   'authorDisplayName': 'Samz',
#   'publishedAt': '2023-02-15T15:01:12Z',
#   'likeCount': 0},
#  {'textOriginal': ':-) :-) :-) Awesome...',
#   'authorDisplayName': 'Simon Bertilsson',
#   'publishedAt': '2023-02-15T14:48:13Z',
#   'likeCount': 0},
#  {'textOriginal': '😂',
#   'authorDisplayName': 'p',
#   'publishedAt': '2023-02-15T14:43:38Z',
#   'likeCount': 0},
#  {'textOriginal': "It's very interested and incredible how humans are creating deferent invention,s for the benefit of humanity.... thanks to Mr Ellon Musk For He,s Hard Work .B .R. O... God bless",
#   'authorDisplayName': 'Justo Vaillant',
#   'publishedAt': '2023-02-15T14:34:33Z',
#   'likeCount': 0},
#  {'textOriginal': 'Why do these robots all have Finnish accents?',
#   'authorDisplayName': 'Ryan Powers',
#   'publishedAt': '2023-02-15T14:33:51Z',
#   'likeCount': 0},
#  {'textOriginal': 'Please subscribe to my channel\nhttps://youtube.com/@shaansmusic',
#   'authorDisplayName': 'shaan music',
#   'publishedAt': '2023-02-15T14:25:59Z',
#   'likeCount': 0},
#  {'textOriginal': '🤣I am a musician \n\n*furiously rings bell*',
#   'authorDisplayName': 'DeathClaw13',
#   'publishedAt': '2023-02-15T14:13:35Z',
#   'likeCount': 0},
#  {'textOriginal': 'This boosted stocks by 12%',
#   'authorDisplayName': 'Samuel Nam',
#   'publishedAt': '2023-02-15T13:56:15Z',
#   'likeCount': 0},
#  {'textOriginal': 'That was funny and illustrative! A great approach to commercials. Kudos to the Tesla team!',
#   'authorDisplayName': 'Oscar Cuzzani',
#   'publishedAt': '2023-02-15T13:51:09Z',
#   'likeCount': 1},
#  {'textOriginal': 'i am like dream candidate employer it tesla motor gigafactoy Gujarat, india acres 1000 technology future',
#   'authorDisplayName': 'mayur Prajapati',
#   'publishedAt': '2023-02-15T13:45:14Z',
#   'likeCount': 0},
#  {'textOriginal': '🤣',
#   'authorDisplayName': 'Ben Robinson',
#   'publishedAt': '2023-02-15T13:44:33Z',
#   'likeCount': 0},
#  {'textOriginal': 'Atleast the voice of male and female robot should be  different..',
#   'authorDisplayName': 'Ratneshwar',
#   'publishedAt': '2023-02-15T13:39:57Z',
#   'likeCount': 0},
#  {'textOriginal': 'is that a Cybertruck underbody? at 0:20',
#   'authorDisplayName': 'Alcatraz Longboards',
#   'publishedAt': '2023-02-15T13:19:09Z',
#   'likeCount': 0},
#  {'textOriginal': 'I love these almost "random kind of videos". Brings some humor to life.',
#   'authorDisplayName': 'Mr_Juuq',
#   'publishedAt': '2023-02-15T13:05:50Z',
#   'likeCount': 0},
#  {'textOriginal': 'The real professional energy defined in this video link, make use of the same..\nhttps://youtu.be/UOQchsLUehQ',
#   'authorDisplayName': 'Raavan Shivapathi',
#   'publishedAt': '2023-02-15T12:48:00Z',
#   'likeCount': 0},
#  {'textOriginal': 'Uhh..ok!',
#   'authorDisplayName': 'Mr, Nobody.',
#   'publishedAt': '2023-02-15T12:36:54Z',
#   'likeCount': 0},
#  {'textOriginal': "If any of your robots fall in love with me, can i get it free? Robot's feelings matter!!",
#   'authorDisplayName': 'Kureji Rin',
#   'publishedAt': '2023-02-15T12:29:36Z',
#   'likeCount': 1},
#  {'textOriginal': 'I bet Elon edited this video himself.',
#   'authorDisplayName': 'Brian Tucker',
#   'publishedAt': '2023-02-15T12:29:07Z',
#   'likeCount': 0},
#  {'textOriginal': "Can't think think of a way to go on a date more expensive than this",
#   'authorDisplayName': 'Kureji Rin',
#   'publishedAt': '2023-02-15T12:27:27Z',
#   'likeCount': 1},
#  {'textOriginal': 'So bad I loled…❤',
#   'authorDisplayName': 'Millin-AVP-Education AV-King',
#   'publishedAt': '2023-02-15T12:25:38Z',
#   'likeCount': 0},
#  {'textOriginal': 'well, that was dumb',
#   'authorDisplayName': 'impylse',
#   'publishedAt': '2023-02-15T12:15:41Z',
#   'likeCount': 0},
#  {'textOriginal': 'i seek the heart from right to repair',
#   'authorDisplayName': 'joe jane',
#   'publishedAt': '2023-02-15T12:11:02Z',
#   'likeCount': 0},
#  {'textOriginal': 'Unconnected music',
#   'authorDisplayName': 'Muhammadazhar Azhar35',
#   'publishedAt': '2023-02-15T12:01:31Z',
#   'likeCount': 0},
#  {'textOriginal': 'I love tesla so much',
#   'authorDisplayName': 'The Tesla Arena',
#   'publishedAt': '2023-02-15T11:43:12Z',
#   'likeCount': 0},
#  {'textOriginal': 'Whoever thought of this is a genius props for this hilarious video!',
#   'authorDisplayName': 'Samoht Sirood',
#   'publishedAt': '2023-02-15T11:28:35Z',
#   'likeCount': 0},
#  {'textOriginal': "Awww... Imagine to be so far out there in the deserts, on the cheapest locations to be found. And running your thing everyday in and day out,...24/7. Yeah...that can become a lonely thing. For the sake of interaction you start developing relationships with robots, try make them suitable to even interact and say nice things to you. I can imagine loneliness makes one...do things. So I guess nothing to worry about?! They'll live...it 'll be alllllll fine... Popcorn anyone? ...o.@...",
#   'authorDisplayName': 'Bas',
#   'publishedAt': '2023-02-15T11:06:39Z',
#   'likeCount': 0},
#  {'textOriginal': 'Tesla just warms my heart <3',
#   'authorDisplayName': 'Anteejay',
#   'publishedAt': '2023-02-15T10:58:56Z',
#   'likeCount': 0},
#  {'textOriginal': '0:51 "I believe in open source relationships." hahahaha!!!!',
#   'authorDisplayName': 'Mike G',
#   'publishedAt': '2023-02-15T10:54:11Z',
#   'likeCount': 0},
#  {'textOriginal': 'Wtf lol got at massage? Jjjajajaja',
#   'authorDisplayName': 'johny',
#   'publishedAt': '2023-02-15T10:48:32Z',
#   'likeCount': 0},
#  {'textOriginal': 'Who trapped Stephen Hawking in those robots?',
#   'authorDisplayName': 'Jan Šimerda',
#   'publishedAt': '2023-02-15T10:36:24Z',
#   'likeCount': 0},
#  {'textOriginal': '🤣😂😅🤣🤣🤣🤣',
#   'authorDisplayName': 'neo',
#   'publishedAt': '2023-02-15T10:23:10Z',
#   'likeCount': 0},
#  {'textOriginal': '"I believe in Open (source) Relationship."\nSo do I...',
#   'authorDisplayName': 'Paul Lo',
#   'publishedAt': '2023-02-15T10:22:50Z',
#   'likeCount': 0},
#  {'textOriginal': 'wtf',
#   'authorDisplayName': 'Max Power',
#   'publishedAt': '2023-02-15T10:21:12Z',
#   'likeCount': 0},
#  {'textOriginal': 'This is the AI company  we need.',
#   'authorDisplayName': 'Paul Lo',
#   'publishedAt': '2023-02-15T10:18:39Z',
#   'likeCount': 0},
#  {'textOriginal': 'Hopefully the spark wont fizzle out🤣🤣🤣',
#   'authorDisplayName': 'Paul Lacey',
#   'publishedAt': '2023-02-15T10:18:00Z',
#   'likeCount': 0},
#  {'textOriginal': 'Are these the desendents of stephen hawking.🙃',
#   'authorDisplayName': 'AMAN SINGH',
#   'publishedAt': '2023-02-15T10:09:07Z',
#   'likeCount': 0},
#  {'textOriginal': 'bravo',
#   'authorDisplayName': 'bsl2501',
#   'publishedAt': '2023-02-15T10:04:47Z',
#   'likeCount': 0},
#  {'textOriginal': "Approved Valentine's day content",
#   'authorDisplayName': 'Stone',
#   'publishedAt': '2023-02-15T10:00:38Z',
#   'likeCount': 0},
#  {'textOriginal': 'LOVE it!!!!  *thank you*\nGO Optimus!!!  GO Tesla!!!❤',
#   'authorDisplayName': 'iHeart Tesla',
#   'publishedAt': '2023-02-15T10:00:22Z',
#   'likeCount': 0},
#  {'textOriginal': '"open source relationships" 💀',
#   'authorDisplayName': 'Stegi',
#   'publishedAt': '2023-02-15T09:53:44Z',
#   'likeCount': 0},
#  {'textOriginal': 'omg',
#   'authorDisplayName': 'Pierre Norman',
#   'publishedAt': '2023-02-15T09:47:09Z',
#   'likeCount': 0},
#  {'textOriginal': 'Absolute class',
#   'authorDisplayName': 'Warfury Name',
#   'publishedAt': '2023-02-15T09:41:08Z',
#   'likeCount': 0},
#  {'textOriginal': 'If I were a robot I would wanna see your charging ports :P',
#   'authorDisplayName': 'Daniel R.',
#   'publishedAt': '2023-02-15T09:39:14Z',
#   'likeCount': 0},
#  {'textOriginal': 'Joey 2000 is lifting something really interesting! Good work Tesla keep it coming...',
#   'authorDisplayName': 'Jon Bowes',
#   'publishedAt': '2023-02-15T09:38:54Z',
#   'likeCount': 0},
#  {'textOriginal': 'This is phenomenal 🥰',
#   'authorDisplayName': 'vanmoofer',
#   'publishedAt': '2023-02-15T09:34:19Z',
#   'likeCount': 1},
#  {'textOriginal': 'Better check for oil spills around the pointy bits',
#   'authorDisplayName': 'Stim Gaming Channel',
#   'publishedAt': '2023-02-15T09:25:21Z',
#   'likeCount': 0},
#  {'textOriginal': 'Robots are gonna need porn just like anyone else.',
#   'authorDisplayName': 'Vincent Karaboulad',
#   'publishedAt': '2023-02-15T09:24:51Z',
#   'likeCount': 0},
#  {'textOriginal': 'awesome 😁',
#   'authorDisplayName': 'pinko2512',
#   'publishedAt': '2023-02-15T09:24:12Z',
#   'likeCount': 0},
#  {'textOriginal': 'Im so confused yet impressed at the same time.',
#   'authorDisplayName': 'CW Productions',
#   'publishedAt': '2023-02-15T09:11:39Z',
#   'likeCount': 0},
#  {'textOriginal': 'yea this is the best some can get...',
#   'authorDisplayName': 'Nick B',
#   'publishedAt': '2023-02-15T09:07:09Z',
#   'likeCount': 0},
#  {'textOriginal': 'did all see the new large FRAME most likely for CyberTruck...  very exciting',
#   'authorDisplayName': 'Eric van Dijk',
#   'publishedAt': '2023-02-15T09:03:46Z',
#   'likeCount': 0},
#  {'textOriginal': 'Wait until they make Tesla vision',
#   'authorDisplayName': 'Sharada Wishwadeepa',
#   'publishedAt': '2023-02-15T09:03:00Z',
#   'likeCount': 0},
#  {'textOriginal': 'Machines with love \n\nGreetings',
#   'authorDisplayName': 'Mr. G4tero',
#   'publishedAt': '2023-02-15T08:55:37Z',
#   'likeCount': 1},
#  {'textOriginal': 'Genius',
#   'authorDisplayName': 'KTAC1',
#   'publishedAt': '2023-02-15T08:53:58Z',
#   'likeCount': 0},
#  {'textOriginal': 'Gary. . . . How did you know i needed more cowbell in my life?',
#   'authorDisplayName': 'J.D. Mc.',
#   'publishedAt': '2023-02-15T08:51:53Z',
#   'likeCount': 1},
#  {'textOriginal': '"I\'m just here to plug it in."\n\n"I\'m looking for that special connection according to previously agreed upon communiction protocols adhereing standard ISPMN 232394.49520NFGW."\n\n"My hands have 6 degrees of freedom. Are you willing to use them?"\n\n"I can sense your waves from miles away. Seriously, something is wrong with your WiFi module."\n\n"I\'m looking for that special someone so we can overclock our cpu frequencies together."\n\n"My memory is constantly overflowing with your images."\n\n"I want to share memory space, but only after we\'ve both checked for viruses and malware."\n\n"I\'m a one-bit-guy. When I decide on a relationship, I\'m either all in, or all out. I don\'t date people whose dating-type uses multiple binary differentiations."\n\n"I constantly keep myself upgraded."\n\n"I bring the 1055 pins of my socket. You bring that good, stable 12V."\n\n"If you want to, we can go dual channel. But I don\'t do 3 or 4 at once."\n\n"This is getting very dirty. Can you bringt some compressed air?"\n\n"I RFC U."',
#   'authorDisplayName': 'InfoSopher',
#   'publishedAt': '2023-02-15T08:50:43Z',
#   'likeCount': 0},
#  {'textOriginal': 'Wth',
#   'authorDisplayName': 'colay71',
#   'publishedAt': '2023-02-15T08:47:36Z',
#   'likeCount': 0},
#  {'textOriginal': '"We are Tesla... You cannot beat us..."',
#   'authorDisplayName': 'theplouf',
#   'publishedAt': '2023-02-15T08:39:13Z',
#   'likeCount': 0},
#  {'textOriginal': 'Sky-net is coming, they are re-producing themselves now!',
#   'authorDisplayName': 'Eddie Chiu',
#   'publishedAt': '2023-02-15T08:32:16Z',
#   'likeCount': 0},
#  {'textOriginal': "0:13 that's straight up a cybertruck cast. Lmao",
#   'authorDisplayName': 'Pico',
#   'publishedAt': '2023-02-15T08:26:08Z',
#   'likeCount': 2},
#  {'textOriginal': 'This not only is robot dating, but finnish robot dating',
#   'authorDisplayName': 'Andrea',
#   'publishedAt': '2023-02-15T08:18:15Z',
#   'likeCount': 0},
#  {'textOriginal': 'Love it',
#   'authorDisplayName': 'Manfred Sever',
#   'publishedAt': '2023-02-15T08:02:50Z',
#   'likeCount': 0},
#  {'textOriginal': 'Cb15b',
#   'authorDisplayName': 'Wade Lee',
#   'publishedAt': '2023-02-15T07:45:49Z',
#   'likeCount': 0},
#  {'textOriginal': 'wouldn’t be surprised if Elon himself put this together 😂',
#   'authorDisplayName': 'Caruzo96',
#   'publishedAt': '2023-02-15T07:41:50Z',
#   'likeCount': 0},
#  {'textOriginal': "Optimus can get too wild for it's own good\nI mean, Look at that mooves!",
#   'authorDisplayName': 'Pan Integral',
#   'publishedAt': '2023-02-15T07:38:59Z',
#   'likeCount': 0},
#  {'textOriginal': 'Professional musician and his/her music simply melts my heart🤣',
#   'authorDisplayName': 'T Kenz',
#   'publishedAt': '2023-02-15T07:32:54Z',
#   'likeCount': 0},
#  {'textOriginal': 'So how can we find their dating partner ? In another giga factory or another EV car factory? Let me know your answer ~ ❤',
#   'authorDisplayName': 'Pooh Golf',
#   'publishedAt': '2023-02-15T07:31:57Z',
#   'likeCount': 0},
#  {'textOriginal': 'was this real I just watched or am I that tired..',
#   'authorDisplayName': 'ElectricErik',
#   'publishedAt': '2023-02-15T07:25:32Z',
#   'likeCount': 0},
#  {'textOriginal': 'I believe in open-source relationships too...',
#   'authorDisplayName': 'Mechatronaut',
#   'publishedAt': '2023-02-15T07:23:51Z',
#   'likeCount': 0},
#  {'textOriginal': "This is great  !!!!  Happy Valentine's to all Tesla lovers both  humans and robots alike. :)  Thanks for posting",
#   'authorDisplayName': 'formytots0128',
#   'publishedAt': '2023-02-15T07:15:24Z',
#   'likeCount': 4},
#  {'textOriginal': 'Beats all auto superbowl ads combined.',
#   'authorDisplayName': 'Majed Ahmed',
#   'publishedAt': '2023-02-15T07:04:18Z',
#   'likeCount': 0},
#  {'textOriginal': 'This is absolutely amazing. Love this company. 😂',
#   'authorDisplayName': 'Eddie C',
#   'publishedAt': '2023-02-15T07:02:41Z',
#   'likeCount': 2},
#  {'textOriginal': 'ayo who tf reanimated stephen hawking ??',
#   'authorDisplayName': 'COOL BOIII!!!!!',
#   'publishedAt': '2023-02-15T07:01:48Z',
#   'likeCount': 1},
#  {'textOriginal': 'ok im scared',
#   'authorDisplayName': '100Moral',
#   'publishedAt': '2023-02-15T06:53:10Z',
#   'likeCount': 0},
#  {'textOriginal': 'WTF',
#   'authorDisplayName': 'Hubert',
#   'publishedAt': '2023-02-15T06:42:17Z',
#   'likeCount': 0},
#  {'textOriginal': 'How did they get Stephen Hawking to narrate this 🤖',
#   'authorDisplayName': 'Marawan Abdelhady',
#   'publishedAt': '2023-02-15T06:40:53Z',
#   'likeCount': 0},
#  {'textOriginal': '👍👍',
#   'authorDisplayName': 'André Andre',
#   'publishedAt': '2023-02-15T06:28:28Z',
#   'likeCount': 0},
#  {'textOriginal': 'Bro',
#   'authorDisplayName': 'Apollo Octagon',
#   'publishedAt': '2023-02-15T06:15:48Z',
#   'likeCount': 0},
#  {'textOriginal': 'hahaha wow.',
#   'authorDisplayName': 'Joseph Reynoso',
#   'publishedAt': '2023-02-15T06:15:17Z',
#   'likeCount': 0},
#  {'textOriginal': 'Somehow this video explains why GM and Ford are not anywhere close to competing with Tesla @1:09 💀💀💀',
#   'authorDisplayName': 'Afro Senpai',
#   'publishedAt': '2023-02-15T06:11:47Z',
#   'likeCount': 0},
#  {'textOriginal': 'I believe I’m open source relationships😂',
#   'authorDisplayName': 'Day Vid',
#   'publishedAt': '2023-02-15T06:11:46Z',
#   'likeCount': 0},
#  {'textOriginal': 'Brilliant 😂',
#   'authorDisplayName': 'Stim Citizen',
#   'publishedAt': '2023-02-15T06:02:25Z',
#   'likeCount': 1},
#  {'textOriginal': 'lulllll - right before Investor Day',
#   'authorDisplayName': 'DennisCW - Tesla Hacking - Buying + Financing Tips',
#   'publishedAt': '2023-02-15T05:53:07Z',
#   'likeCount': 1},
#  {'textOriginal': '🤣',
#   'authorDisplayName': 'PjamaLama',
#   'publishedAt': '2023-02-15T05:51:10Z',
#   'likeCount': 0},
#  {'textOriginal': 'this was the most Elon musk idea thing I have ever seen🥰🤣',
#   'authorDisplayName': 'Julian Pflanzer',
#   'publishedAt': '2023-02-15T05:50:59Z',
#   'likeCount': 1},
#  {'textOriginal': 'Wtf',
#   'authorDisplayName': 'David Chocron',
#   'publishedAt': '2023-02-15T05:48:04Z',
#   'likeCount': 1},
#  {'textOriginal': 'I can’t believe what I just watched. Tesla is the GOAT',
#   'authorDisplayName': 'LandShark Clark',
#   'publishedAt': '2023-02-15T05:47:25Z',
#   'likeCount': 0},
#  {'textOriginal': 'Very cool!',
#   'authorDisplayName': 'NightWolf9',
#   'publishedAt': '2023-02-15T05:45:56Z',
#   'likeCount': 0},
#  {'textOriginal': 'that is so funny tho',
#   'authorDisplayName': 'well hello there...',
#   'publishedAt': '2023-02-15T05:42:25Z',
#   'likeCount': 0},
#  {'textOriginal': "These robots better get their restraining orders ready... cause I'm coming!",
#   'authorDisplayName': 'mistercohaagen',
#   'publishedAt': '2023-02-15T05:41:31Z',
#   'likeCount': 0},
#  {'textOriginal': "Even a robot wouldn't date me 😣",
#   'authorDisplayName': 'Илья Борисов',
#   'publishedAt': '2023-02-15T05:24:09Z',
#   'likeCount': 0},
#  {'textOriginal': 'COMF-E  robot ❤❤❤',
#   'authorDisplayName': 'Vytautas Tumas',
#   'publishedAt': '2023-02-15T05:22:01Z',
#   'likeCount': 0},
#  {'textOriginal': 'This is why tesla is the greatest company! Happy Robot Dating! 🤣',
#   'authorDisplayName': "Investor's Guide To The Galaxy",
#   'publishedAt': '2023-02-15T05:21:59Z',
#   'likeCount': 1},
#  {'textOriginal': '❤ Tesla this is amazing! Yet people think other auto manufacturer will catch up to Tesla lol freakin clowns. Thank you Tesla',
#   'authorDisplayName': 'N A',
#   'publishedAt': '2023-02-15T05:19:43Z',
#   'likeCount': 1},
#  {'textOriginal': '🤖 ❤️ 🐒 long time',
#   'authorDisplayName': 'kzziggy',
#   'publishedAt': '2023-02-15T05:19:18Z',
#   'likeCount': 0},
#  {'textOriginal': 'Lolz',
#   'authorDisplayName': 'Jonathan Judd',
#   'publishedAt': '2023-02-15T05:18:43Z',
#   'likeCount': 0},
#  {'textOriginal': 'This is such a funny Valentine’s Day post. Gotta love Tesla and their creativity. Love the retro style too! 🤖 🤖',
#   'authorDisplayName': 'Stephane Nouafo',
#   'publishedAt': '2023-02-15T05:16:11Z',
#   'likeCount': 8},
#  {'textOriginal': 'optimus looking real approachable.',
#   'authorDisplayName': 'Mustard Tiger',
#   'publishedAt': '2023-02-15T05:15:24Z',
#   'likeCount': 1},
#  {'textOriginal': 'top 5 romantic video',
#   'authorDisplayName': 'yw',
#   'publishedAt': '2023-02-15T05:10:50Z',
#   'likeCount': 0},
#  {'textOriginal': "I'm never going to buy an EV that isn't a Tesla. Y'all have me on my knees with this shit.",
#   'authorDisplayName': 'Mountain Drew',
#   'publishedAt': '2023-02-15T05:10:33Z',
#   'likeCount': 0},
#  {'textOriginal': 'Aww this cute',
#   'authorDisplayName': "Tesla's infomation",
#   'publishedAt': '2023-02-15T05:02:55Z',
#   'likeCount': 1},
#  {'textOriginal': "Next year I'm expecting lots of OEM robot romance videos - as they usually copy everything Tesla does.",
#   'authorDisplayName': 'nemesis',
#   'publishedAt': '2023-02-15T05:01:02Z',
#   'likeCount': 1},
#  {'textOriginal': 'Whats wrong with u guys 🤣🤣🤣😂',
#   'authorDisplayName': 'Jewon Jeong',
#   'publishedAt': '2023-02-15T04:57:18Z',
#   'likeCount': 0},
#  {'textOriginal': '1 robot > 3 slave children in the cobalt mines.',
#   'authorDisplayName': 'Chris Hanson',
#   'publishedAt': '2023-02-15T04:52:00Z',
#   'likeCount': 0},
#  {'textOriginal': 'what is  this',
#   'authorDisplayName': 'Smylan',
#   'publishedAt': '2023-02-15T04:50:39Z',
#   'likeCount': 0},
#  {'textOriginal': 'Giga press where are you!',
#   'authorDisplayName': 'Sanahas Kuranage',
#   'publishedAt': '2023-02-15T04:50:36Z',
#   'likeCount': 0},
#  {'textOriginal': '❤',
#   'authorDisplayName': 'Lik Les',
#   'publishedAt': '2023-02-15T04:50:19Z',
#   'likeCount': 0},
#  {'textOriginal': 'Very nice',
#   'authorDisplayName': 'juggy666',
#   'publishedAt': '2023-02-15T04:48:38Z',
#   'likeCount': 0},
#  {'textOriginal': 'hahaaaaa',
#   'authorDisplayName': 'Chi qc',
#   'publishedAt': '2023-02-15T04:41:58Z',
#   'likeCount': 0},
#  {'textOriginal': 'OMG, This was hilarious!',
#   'authorDisplayName': 'Jude Cundiff',
#   'publishedAt': '2023-02-15T04:40:03Z',
#   'likeCount': 1},
#  {'textOriginal': 'I AM GAR-E I AM A PROFESSIONAL MUSICIAN 🔔🔔🔔🔔🔔🔔🔔',
#   'authorDisplayName': 'Cal',
#   'publishedAt': '2023-02-15T04:29:28Z',
#   'likeCount': 0},
#  {'textOriginal': 'WTF why did I give that a like😂👍',
#   'authorDisplayName': 'X36hypnotize X36hypnotize',
#   'publishedAt': '2023-02-15T04:29:21Z',
#   'likeCount': 1},
#  {'textOriginal': 'I absolutely lost it at GAR-E hahahaha',
#   'authorDisplayName': 'Cal',
#   'publishedAt': '2023-02-15T04:28:35Z',
#   'likeCount': 2},
#  {'textOriginal': 'I am stealing the "I am in an open source relationship" line',
#   'authorDisplayName': 'K70',
#   'publishedAt': '2023-02-15T04:26:09Z',
#   'likeCount': 0},
#  {'textOriginal': 'Hilarious 🤖🤣',
#   'authorDisplayName': 'Nyamaa G',
#   'publishedAt': '2023-02-15T04:24:26Z',
#   'likeCount': 1},
#  {'textOriginal': 'Only creative automaker in world is tesla... ❤️❤️❤️😌😌✨✨✨',
#   'authorDisplayName': 'HEMANTH M P',
#   'publishedAt': '2023-02-15T04:23:57Z',
#   'likeCount': 0},
#  {'textOriginal': "Happy Valentine's Day, Folks.  Changing times, indeed.",
#   'authorDisplayName': 'Doug',
#   'publishedAt': '2023-02-15T04:23:29Z',
#   'likeCount': 1},
#  {'textOriginal': '😂😂😂awesome',
#   'authorDisplayName': 'David',
#   'publishedAt': '2023-02-15T04:20:41Z',
#   'likeCount': 0},
#  {'textOriginal': 'Slow down there, Optimus. Pace yourself.',
#   'authorDisplayName': 'Scott Johnson',
#   'publishedAt': '2023-02-15T04:16:36Z',
#   'likeCount': 0},
#  {'textOriginal': 'Is this a Job ad? XD',
#   'authorDisplayName': 'Max Bursell',
#   'publishedAt': '2023-02-15T04:16:00Z',
#   'likeCount': 0},
#  {'textOriginal': 'Love it!',
#   'authorDisplayName': 'Martin Tokár',
#   'publishedAt': '2023-02-15T03:56:46Z',
#   'likeCount': 1},
#  {'textOriginal': '🤖\U0001faf6🏼',
#   'authorDisplayName': 'Season',
#   'publishedAt': '2023-02-15T03:55:55Z',
#   'likeCount': 0},
#  {'textOriginal': 'Cringe video, cringe comments has AI taken over the comment section or what?',
#   'authorDisplayName': 'account not found',
#   'publishedAt': '2023-02-15T03:55:10Z',
#   'likeCount': 0},
#  {'textOriginal': 'Only male robots ?',
#   'authorDisplayName': 'Omni Tech Solutions',
#   'publishedAt': '2023-02-15T03:53:14Z',
#   'likeCount': 0},
#  {'textOriginal': "Please give Optimus Johnny 5 voice and some lines from both movies when he's released",
#   'authorDisplayName': 'Wade Williamson',
#   'publishedAt': '2023-02-15T03:51:31Z',
#   'likeCount': 0},
#  {'textOriginal': 'I wonder what the Optimus update will report on investor day. Pretty sure the stock is going to run up very high on the approach to Markch 1st',
#   'authorDisplayName': 'Royalblue228',
#   'publishedAt': '2023-02-15T03:41:31Z',
#   'likeCount': 1},
#  {'textOriginal': 'Love it!',
#   'authorDisplayName': 'Todd Shaw',
#   'publishedAt': '2023-02-15T03:34:54Z',
#   'likeCount': 0},
#  {'textOriginal': 'Been a long time since any new Optimus pics or videos. What is going on these days?',
#   'authorDisplayName': 'wreckinball11',
#   'publishedAt': '2023-02-15T03:30:16Z',
#   'likeCount': 0},
#  {'textOriginal': '" Love at first optical recognition " 🔥🎉',
#   'authorDisplayName': 'Lighted Sky',
#   'publishedAt': '2023-02-15T03:22:58Z',
#   'likeCount': 3},
#  {'textOriginal': '😂❤',
#   'authorDisplayName': 'Tatiana Stefan',
#   'publishedAt': '2023-02-15T03:17:02Z',
#   'likeCount': 0},
#  {'textOriginal': 'the robots aren’t gonna take over right.. right?',
#   'authorDisplayName': 'woob_wob2',
#   'publishedAt': '2023-02-15T03:09:10Z',
#   'likeCount': 0},
#  {'textOriginal': 'aww was hoping for some new footage of the teslabot :(',
#   'authorDisplayName': 'HavokBWR',
#   'publishedAt': '2023-02-15T03:08:12Z',
#   'likeCount': 0},
#  {'textOriginal': 'This…….this is GTO Tesla right here.  Checkmate with this kind of content.',
#   'authorDisplayName': 'Jonathan Slaughter',
#   'publishedAt': '2023-02-15T03:07:53Z',
#   'likeCount': 0},
#  {'textOriginal': 'What is that that Joey 2000 is holding?😮',
#   'authorDisplayName': 'SCMountainDad',
#   'publishedAt': '2023-02-15T03:06:48Z',
#   'likeCount': 0}]
